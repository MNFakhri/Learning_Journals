# %% [markdown]
# # Solving Case 2

# %% [markdown]
# ### data cleaning

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
property_data = pd.read_csv("property_data.csv")

property_data
# Out:
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED NUM_BEDROOMS NUM_BATH SQ_FT
# 0  100001000.0   104.0      PUTNAM            Y            3        1  1000
# 1  100002000.0   197.0   LEXINGTON            N            3      1.5    --
# 2  100003000.0     NaN   LEXINGTON            N          NaN        1   850
# 3  100004000.0   201.0    BERKELEY           12            1      NaN   700
# 4          NaN   203.0    BERKELEY            Y            3        2  1600
# 5  100006000.0   207.0    BERKELEY            Y          NaN        1   800
# 6  100007000.0     NaN  WASHINGTON          NaN            2   HURLEY   950
# 7  100008000.0   213.0     TREMONT            Y           --        1   NaN
# 8  100009000.0   215.0     TREMONT            Y           na        2  1800

# %%
property_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   PID           8 non-null      float64
#  1   ST_NUM        7 non-null      float64
#  2   ST_NAME       9 non-null      object
#  3   OWN_OCCUPIED  8 non-null      object
#  4   NUM_BEDROOMS  7 non-null      object
#  5   NUM_BATH      8 non-null      object
#  6   SQ_FT         8 non-null      object
# dtypes: float64(2), object(5)
# memory usage: 632.0+ bytes

# %%
property_data["OWN_OCCUPIED"]
# Out:
# 0      Y
# 1      N
# 2      N
# 3     12
# 4      Y
# 5      Y
# 6    NaN
# 7      Y
# 8      Y
# Name: OWN_OCCUPIED, dtype: object

# %%
property_data["ST_NUM"]
# Out:
# 0    104.0
# 1    197.0
# 2      NaN
# 3    201.0
# 4    203.0
# 5    207.0
# 6      NaN
# 7    213.0
# 8    215.0
# Name: ST_NUM, dtype: float64

# %%
property_data["ST_NUM"].isnull()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# 5    False
# 6     True
# 7    False
# 8    False
# Name: ST_NUM, dtype: bool

# %%
property_data["ST_NUM"].isna()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# 5    False
# 6     True
# 7    False
# 8    False
# Name: ST_NUM, dtype: bool

# %%
property_data
# Out:
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED NUM_BEDROOMS NUM_BATH SQ_FT
# 0  100001000.0   104.0      PUTNAM            Y            3        1  1000
# 1  100002000.0   197.0   LEXINGTON            N            3      1.5    --
# 2  100003000.0     NaN   LEXINGTON            N          NaN        1   850
# 3  100004000.0   201.0    BERKELEY           12            1      NaN   700
# 4          NaN   203.0    BERKELEY            Y            3        2  1600
# 5  100006000.0   207.0    BERKELEY            Y          NaN        1   800
# 6  100007000.0     NaN  WASHINGTON          NaN            2   HURLEY   950
# 7  100008000.0   213.0     TREMONT            Y           --        1   NaN
# 8  100009000.0   215.0     TREMONT            Y           na        2  1800

# %%
property_data["NUM_BEDROOMS"]
# Out:
# 0      3
# 1      3
# 2    NaN
# 3      1
# 4      3
# 5    NaN
# 6      2
# 7     --
# 8     na
# Name: NUM_BEDROOMS, dtype: object

# %%
property_data["NUM_BEDROOMS"].isnull()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# 5     True
# 6    False
# 7    False
# 8    False
# Name: NUM_BEDROOMS, dtype: bool

# %%
missing_values = ["na","--","n\a","n/a","HURLEY"]

# %%
property_data = pd.read_csv("property_data.csv", na_values = missing_values)

property_data
# Out:
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED  NUM_BEDROOMS  NUM_BATH  \
# 0  100001000.0   104.0      PUTNAM            Y           3.0       1.0
# 1  100002000.0   197.0   LEXINGTON            N           3.0       1.5
# 2  100003000.0     NaN   LEXINGTON            N           NaN       1.0
# 3  100004000.0   201.0    BERKELEY           12           1.0       NaN
# 4          NaN   203.0    BERKELEY            Y           3.0       2.0
# 5  100006000.0   207.0    BERKELEY            Y           NaN       1.0
# 6  100007000.0     NaN  WASHINGTON          NaN           2.0       NaN
# 7  100008000.0   213.0     TREMONT            Y           NaN       1.0
# 8  100009000.0   215.0     TREMONT            Y           NaN       2.0
#
#     SQ_FT
# 0  1000.0
# 1     NaN
# 2   850.0
# 3   700.0
# 4  1600.0
# 5   800.0
# 6   950.0
# 7     NaN
# 8  1800.0

# %%
property_data["OWN_OCCUPIED"].unique()
# Out:
# array(['Y', 'N', '12', nan], dtype=object)

# %%
property_data["OWN_OCCUPIED"]
# Out:
# 0      Y
# 1      N
# 2      N
# 3     12
# 4      Y
# 5      Y
# 6    NaN
# 7      Y
# 8      Y
# Name: OWN_OCCUPIED, dtype: object

# %%
property_data["OWN_OCCUPIED"].isnull()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6     True
# 7    False
# 8    False
# Name: OWN_OCCUPIED, dtype: bool

# %%
i=0
for row in property_data['OWN_OCCUPIED']:
    try:
        int(row)
        property_data.loc[i, 'OWN_OCCUPIED']=np.nan
    except ValueError:
        pass
    i = i +1

# %%
property_data
# Out:
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED  NUM_BEDROOMS  NUM_BATH  \
# 0  100001000.0   104.0      PUTNAM            Y           3.0       1.0
# 1  100002000.0   197.0   LEXINGTON            N           3.0       1.5
# 2  100003000.0     NaN   LEXINGTON            N           NaN       1.0
# 3  100004000.0   201.0    BERKELEY          NaN           1.0       NaN
# 4          NaN   203.0    BERKELEY            Y           3.0       2.0
# 5  100006000.0   207.0    BERKELEY            Y           NaN       1.0
# 6  100007000.0     NaN  WASHINGTON          NaN           2.0       NaN
# 7  100008000.0   213.0     TREMONT            Y           NaN       1.0
# 8  100009000.0   215.0     TREMONT            Y           NaN       2.0
#
#     SQ_FT
# 0  1000.0
# 1     NaN
# 2   850.0
# 3   700.0
# 4  1600.0
# 5   800.0
# 6   950.0
# 7     NaN
# 8  1800.0

# %%
property_data["OWN_OCCUPIED"]
# Out:
# 0      Y
# 1      N
# 2      N
# 3    NaN
# 4      Y
# 5      Y
# 6    NaN
# 7      Y
# 8      Y
# Name: OWN_OCCUPIED, dtype: object

# %%
property_data.isnull()
# Out:
#      PID  ST_NUM  ST_NAME  OWN_OCCUPIED  NUM_BEDROOMS  NUM_BATH  SQ_FT
# 0  False   False    False         False         False     False  False
# 1  False   False    False         False         False     False   True
# 2  False    True    False         False          True     False  False
# 3  False   False    False          True         False      True  False
# 4   True   False    False         False         False     False  False
# 5  False   False    False         False          True     False  False
# 6  False    True    False          True         False      True  False
# 7  False   False    False         False          True     False   True
# 8  False   False    False         False          True     False  False

# %%
property_data.isnull().sum()
# Out:
# PID             1
# ST_NUM          2
# ST_NAME         0
# OWN_OCCUPIED    2
# NUM_BEDROOMS    4
# NUM_BATH        2
# SQ_FT           2
# dtype: int64

# %%
property_data.isnull().values.any()
# Out:
# True

# %%
property_data["ST_NUM"]
# Out:
# 0    104.0
# 1    197.0
# 2      NaN
# 3    201.0
# 4    203.0
# 5    207.0
# 6      NaN
# 7    213.0
# 8    215.0
# Name: ST_NUM, dtype: float64

# %%
property_data["ST_NUM"].fillna(125, inplace=True)

property_data["ST_NUM"]
# Out:
# 0    104.0
# 1    197.0
# 2    125.0
# 3    201.0
# 4    203.0
# 5    207.0
# 6    125.0
# 7    213.0
# 8    215.0
# Name: ST_NUM, dtype: float64

# %%
med = property_data['NUM_BEDROOMS'].median()

property_data['NUM_BEDROOMS'].fillna(med, inplace=True)

property_data
# Out:
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED  NUM_BEDROOMS  NUM_BATH  \
# 0  100001000.0   104.0      PUTNAM            Y           3.0       1.0
# 1  100002000.0   197.0   LEXINGTON            N           3.0       1.5
# 2  100003000.0   125.0   LEXINGTON            N           3.0       1.0
# 3  100004000.0   201.0    BERKELEY          NaN           1.0       NaN
# 4          NaN   203.0    BERKELEY            Y           3.0       2.0
# 5  100006000.0   207.0    BERKELEY            Y           3.0       1.0
# 6  100007000.0   125.0  WASHINGTON          NaN           2.0       NaN
# 7  100008000.0   213.0     TREMONT            Y           3.0       1.0
# 8  100009000.0   215.0     TREMONT            Y           3.0       2.0
#
#     SQ_FT
# 0  1000.0
# 1     NaN
# 2   850.0
# 3   700.0
# 4  1600.0
# 5   800.0
# 6   950.0
# 7     NaN
# 8  1800.0

# %%
property_data["NUM_BATH"].unique()
# Out:
# array([1. , 1.5, nan, 2. ])

# %%
med1 = property_data["NUM_BATH"].median()

property_data["NUM_BATH"].fillna(med1, inplace=True)

property_data
# Out:
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED  NUM_BEDROOMS  NUM_BATH  \
# 0  100001000.0   104.0      PUTNAM            Y           3.0       1.0
# 1  100002000.0   197.0   LEXINGTON            N           3.0       1.5
# 2  100003000.0   125.0   LEXINGTON            N           3.0       1.0
# 3  100004000.0   201.0    BERKELEY          NaN           1.0       1.0
# 4          NaN   203.0    BERKELEY            Y           3.0       2.0
# 5  100006000.0   207.0    BERKELEY            Y           3.0       1.0
# 6  100007000.0   125.0  WASHINGTON          NaN           2.0       1.0
# 7  100008000.0   213.0     TREMONT            Y           3.0       1.0
# 8  100009000.0   215.0     TREMONT            Y           3.0       2.0
#
#     SQ_FT
# 0  1000.0
# 1     NaN
# 2   850.0
# 3   700.0
# 4  1600.0
# 5   800.0
# 6   950.0
# 7     NaN
# 8  1800.0

# %%
data_pid4 = property_data.loc[4,["PID"]]
data_pid4
# Out:
# PID    NaN
# Name: 4, dtype: object

# %%
data_pid3 = property_data.loc[3,["PID"]]
data_pid2 = property_data.loc[2,["PID"]]
print(data_pid3)
print(data_pid2)
# Out:
# PID    100004000.0
# Name: 3, dtype: object
# PID    100003000.0
# Name: 2, dtype: object

# %%
selisih = data_pid3 - data_pid2

selisih
# Out:
# PID    1000.0
# dtype: object

# %%
data_pid5 = data_pid3 + selisih

data_pid5
# Out:
# PID    100005000.0
# dtype: object

# %%
property_data["PID"].fillna(100005000.0, inplace=True)

property_data
# Out:
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED  NUM_BEDROOMS  NUM_BATH  \
# 0  100001000.0   104.0      PUTNAM            Y           3.0       1.0
# 1  100002000.0   197.0   LEXINGTON            N           3.0       1.5
# 2  100003000.0   125.0   LEXINGTON            N           3.0       1.0
# 3  100004000.0   201.0    BERKELEY          NaN           1.0       1.0
# 4  100005000.0   203.0    BERKELEY            Y           3.0       2.0
# 5  100006000.0   207.0    BERKELEY            Y           3.0       1.0
# 6  100007000.0   125.0  WASHINGTON          NaN           2.0       1.0
# 7  100008000.0   213.0     TREMONT            Y           3.0       1.0
# 8  100009000.0   215.0     TREMONT            Y           3.0       2.0
#
#     SQ_FT
# 0  1000.0
# 1     NaN
# 2   850.0
# 3   700.0
# 4  1600.0
# 5   800.0
# 6   950.0
# 7     NaN
# 8  1800.0

# %%
rata_rata = property_data["SQ_FT"].mean()

property_data["SQ_FT"].fillna(rata_rata, inplace=True)

property_data
# Out:
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED  NUM_BEDROOMS  NUM_BATH  \
# 0  100001000.0   104.0      PUTNAM            Y           3.0       1.0
# 1  100002000.0   197.0   LEXINGTON            N           3.0       1.5
# 2  100003000.0   125.0   LEXINGTON            N           3.0       1.0
# 3  100004000.0   201.0    BERKELEY          NaN           1.0       1.0
# 4  100005000.0   203.0    BERKELEY            Y           3.0       2.0
# 5  100006000.0   207.0    BERKELEY            Y           3.0       1.0
# 6  100007000.0   125.0  WASHINGTON          NaN           2.0       1.0
# 7  100008000.0   213.0     TREMONT            Y           3.0       1.0
# 8  100009000.0   215.0     TREMONT            Y           3.0       2.0
#
#     SQ_FT
# 0  1000.0
# 1  1100.0
# 2   850.0
# 3   700.0
# 4  1600.0
# 5   800.0
# 6   950.0
# 7  1100.0
# 8  1800.0

# %%
property_data["OWN_OCCUPIED"].fillna("N", inplace=True)

property_data
# Out:
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED  NUM_BEDROOMS  NUM_BATH  \
# 0  100001000.0   104.0      PUTNAM            Y           3.0       1.0
# 1  100002000.0   197.0   LEXINGTON            N           3.0       1.5
# 2  100003000.0   125.0   LEXINGTON            N           3.0       1.0
# 3  100004000.0   201.0    BERKELEY            N           1.0       1.0
# 4  100005000.0   203.0    BERKELEY            Y           3.0       2.0
# 5  100006000.0   207.0    BERKELEY            Y           3.0       1.0
# 6  100007000.0   125.0  WASHINGTON            N           2.0       1.0
# 7  100008000.0   213.0     TREMONT            Y           3.0       1.0
# 8  100009000.0   215.0     TREMONT            Y           3.0       2.0
#
#     SQ_FT
# 0  1000.0
# 1  1100.0
# 2   850.0
# 3   700.0
# 4  1600.0
# 5   800.0
# 6   950.0
# 7  1100.0
# 8  1800.0
