# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_mentah = pd.read_csv("Mall Customers.csv")
data_mentah
# Out:
#      Unnamed: 0  CustomerID  Gender  Age  Annual Income (k$)  \
# 0             0           1    Male   19                  15
# 1             1           2    Male   21                  15
# 2             2           3  Female   20                  16
# 3             3           4  Female   23                  16
# 4             4           5  Female   31                  17
# ..          ...         ...     ...  ...                 ...
# 195         195         196  Female   35                 120
# 196         196         197  Female   45                 126
# 197         197         198    Male   32                 126
# 198         198         199    Male   32                 137
# 199         199         200    Male   30                 137
#
#      Spending Score (1-100)  Label
# 0                        39      0
# 1                        81      4
# 2                         6      0
# 3                        77      4
# 4                        40      0
# ...

# %%
del data_mentah["Unnamed: 0"]
data_mentah
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)  \
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
#      Label
# 0        0
# 1        4
# 2        0
# 3        4
# 4        0
# ..     ...
# ...

# %%
data_mentah.describe()
# Out:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)  \
# count  200.000000  200.000000          200.000000              200.000000
# mean   100.500000   38.850000           60.560000               50.200000
# std     57.879185   13.969007           26.264721               25.823522
# min      1.000000   18.000000           15.000000                1.000000
# 25%     50.750000   28.750000           41.500000               34.750000
# 50%    100.500000   36.000000           61.500000               50.000000
# 75%    150.250000   49.000000           78.000000               73.000000
# max    200.000000   70.000000          137.000000               99.000000
#
#             Label
# count  200.000000
# mean     2.190000
# std      1.208804
# min      0.000000
# 25%      1.000000
# 50%      3.000000
# 75%      3.000000
# max      4.000000

# %%
data_mentah["Label"].unique()
# Out:
# array([0, 4, 3, 1, 2], dtype=int64)

# %%
data_mentah["Gender"].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
data_mentah["Age"].unique()
# Out:
# array([19, 21, 20, 23, 31, 22, 35, 64, 30, 67, 58, 24, 37, 52, 25, 46, 54,
#        29, 45, 40, 60, 53, 18, 49, 42, 36, 65, 48, 50, 27, 33, 59, 47, 51,
#        69, 70, 63, 43, 68, 32, 26, 57, 38, 55, 34, 66, 39, 44, 28, 56, 41],
#       dtype=int64)

# %%
data_mentah["Spending Score (1-100)"].unique()
# Out:
# array([39, 81,  6, 77, 40, 76, 94,  3, 72, 14, 99, 15, 13, 79, 35, 66, 29,
#        98, 73,  5, 82, 32, 61, 31, 87,  4, 92, 17, 26, 75, 36, 28, 65, 55,
#        47, 42, 52, 60, 54, 45, 41, 50, 46, 51, 56, 59, 48, 49, 53, 44, 57,
#        58, 43, 91, 95, 11,  9, 34, 71, 88,  7, 10, 93, 12, 97, 74, 22, 90,
#        20, 16, 89,  1, 78, 83, 27, 63, 86, 69, 24, 68, 85, 23,  8, 18],
#       dtype=int64)

# %%
data_male = data_mentah.loc[data_mentah["Gender"] == "Male"]
data_male
# Out:
#      CustomerID Gender  Age  Annual Income (k$)  Spending Score (1-100)  Label
# 0             1   Male   19                  15                      39      0
# 1             2   Male   21                  15                      81      4
# 8             9   Male   64                  19                       3      0
# 10           11   Male   67                  19                      14      0
# 14           15   Male   37                  20                      13      0
# ..          ...    ...  ...                 ...                     ...    ...
# 187         188   Male   28                 101                      68      1
# 192         193   Male   33                 113                       8      2
# 197         198   Male   32                 126                      74      1
# 198         199   Male   32                 137                      18      2
# 199         200   Male   30                 137                      83      1
#
# [88 rows x 6 columns]

# %%
data_female = data_mentah.loc[data_mentah["Gender"] == "Female"]
data_female
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)  \
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# 5             6  Female   22                  17                      76
# 6             7  Female   35                  18                       6
# ..          ...     ...  ...                 ...                     ...
# 191         192  Female   32                 103                      69
# 193         194  Female   38                 113                      91
# 194         195  Female   47                 120                      16
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
#
#      Label
# 2        0
# 3        4
# 4        0
# 5        4
# 6        0
# ..     ...
# ...

# %%
data_label_0 = data_mentah.loc[data_mentah["Label"] == 0]
data_label_0
# Out:
#     CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)  Label
# 0            1    Male   19                  15                      39      0
# 2            3  Female   20                  16                       6      0
# 4            5  Female   31                  17                      40      0
# 6            7  Female   35                  18                       6      0
# 8            9    Male   64                  19                       3      0
# 10          11    Male   67                  19                      14      0
# 12          13  Female   58                  20                      15      0
# 14          15    Male   37                  20                      13      0
# 16          17  Female   35                  21                      35      0
# 18          19    Male   52                  23                      29      0
# 20          21    Male   35                  24                      35      0
# ...

# %%
data_label_1 = data_mentah.loc[data_mentah["Label"] == 1]
data_label_1
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)  \
# 123         124    Male   39                  69                      91
# 125         126  Female   31                  70                      77
# 127         128    Male   40                  71                      95
# 129         130    Male   38                  71                      75
# 131         132    Male   39                  71                      75
# 133         134  Female   31                  72                      71
# 135         136  Female   29                  73                      88
# 137         138    Male   32                  73                      73
# 139         140  Female   35                  74                      72
# 141         142    Male   32                  75                      93
# 143         144  Female   32                  76                      87
# 145         146    Male   28                  77                      97
# ...

# %%
data_label_2 = data_mentah.loc[data_mentah["Label"] == 2]
data_label_2
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)  \
# 124         125  Female   23                  70                      29
# 128         129    Male   59                  71                      11
# 130         131    Male   47                  71                       9
# 132         133  Female   25                  72                      34
# 134         135    Male   20                  73                       5
# 136         137  Female   44                  73                       7
# 138         139    Male   19                  74                      10
# 140         141  Female   57                  75                       5
# 142         143  Female   28                  76                      40
# 144         145    Male   25                  77                      12
# 146         147    Male   48                  77                      36
# 148         149  Female   34                  78                      22
# ...

# %%
data_label_3 = data_mentah.loc[data_mentah["Label"] == 3]
data_label_3
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)  \
# 43           44  Female   31                  39                      61
# 46           47  Female   50                  40                      55
# 47           48  Female   27                  40                      47
# 48           49  Female   29                  40                      42
# 49           50  Female   31                  40                      42
# ..          ...     ...  ...                 ...                     ...
# 119         120  Female   50                  67                      57
# 120         121    Male   27                  67                      56
# 121         122  Female   38                  67                      40
# 122         123  Female   40                  69                      58
# 126         127    Male   43                  71                      35
#
#      Label
# 43       3
# 46       3
# 47       3
# 48       3
# 49       3
# ..     ...
# ...

# %%
data_label_4 = data_mentah.loc[data_mentah["Label"] == 4]
data_label_4
# Out:
#     CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)  Label
# 1            2    Male   21                  15                      81      4
# 3            4  Female   23                  16                      77      4
# 5            6  Female   22                  17                      76      4
# 7            8  Female   23                  18                      94      4
# 9           10  Female   30                  19                      72      4
# 11          12  Female   35                  19                      99      4
# 13          14  Female   24                  20                      77      4
# 15          16    Male   22                  20                      79      4
# 17          18    Male   20                  21                      66      4
# 19          20  Female   35                  23                      98      4
# 21          22    Male   25                  24                      73      4
# ...

# %%
data_mentah.groupby(by="Gender")[["Age"]].mean()
# Out:
#               Age
# Gender
# Female  38.098214
# Male    39.806818

# %%
data_mentah.groupby(by="Gender")[["Annual Income (k$)"]].mean()
# Out:
#         Annual Income (k$)
# Gender
# Female           59.250000
# Male             62.227273

# %%
data_mentah.groupby(by="Age")[["Annual Income (k$)"]].mean()
# Out:
#      Annual Income (k$)
# Age
# 18            51.250000
# 19            57.000000
# 20            41.600000
# 21            38.800000
# 22            31.333333
# 23            41.500000
# 24            39.250000
# 25            57.666667
# 26            58.000000
# 27            63.166667
# 28            85.250000
# 29            63.600000
# 30            76.142857
# 31            48.375000
# 32            87.181818
# 33            80.333333
# 34            79.000000
# 35            46.666667
# 36            81.000000
# 37            65.000000
# 38            74.500000
# 39            72.666667
# 40            61.666667
# 41           101.000000
# 42            60.000000
# 43            65.666667
# 44            75.500000
# 45            69.333333
# 46            59.000000
# 47            70.166667
# 48            58.200000
# 49            51.000000
# 50            58.600000
# 51            55.500000
# 52            55.500000
# 53            39.500000
# 54            59.750000
# ...

# %%
np.round(data_mentah.groupby(by="Gender")[["Spending Score (1-100)"]].mean())
# Out:
#         Spending Score (1-100)
# Gender
# Female                    52.0
# Male                      49.0

# %%
data_mentah.groupby(by="Label")[["Annual Income (k$)"]].mean()
# Out:
#        Annual Income (k$)
# Label
# 0               26.304348
# 1               86.538462
# 2               87.432432
# 3               54.822785
# 4               25.727273

# %%
data_mentah.groupby(by="Age")[["Annual Income (k$)"]].mean()
# Out:
#      Annual Income (k$)
# Age
# 18            51.250000
# 19            57.000000
# 20            41.600000
# 21            38.800000
# 22            31.333333
# 23            41.500000
# 24            39.250000
# 25            57.666667
# 26            58.000000
# 27            63.166667
# 28            85.250000
# 29            63.600000
# 30            76.142857
# 31            48.375000
# 32            87.181818
# 33            80.333333
# 34            79.000000
# 35            46.666667
# 36            81.000000
# 37            65.000000
# 38            74.500000
# 39            72.666667
# 40            61.666667
# 41           101.000000
# 42            60.000000
# 43            65.666667
# 44            75.500000
# 45            69.333333
# 46            59.000000
# 47            70.166667
# 48            58.200000
# 49            51.000000
# 50            58.600000
# 51            55.500000
# 52            55.500000
# 53            39.500000
# 54            59.750000
# ...

# %%
plt.hist(data_mentah.groupby(by="Age")[["Annual Income (k$)"]].mean())
# Out:
# (array([ 1.,  1.,  6.,  8., 13.,  9.,  6.,  4.,  2.,  1.]),
#  array([ 19. ,  27.2,  35.4,  43.6,  51.8,  60. ,  68.2,  76.4,  84.6,
#          92.8, 101. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(data_mentah["Age"])
# Out:
# (array([31., 19., 34., 29., 16., 26., 15., 10.,  6., 14.]),
#  array([18. , 23.2, 28.4, 33.6, 38.8, 44. , 49.2, 54.4, 59.6, 64.8, 70. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(data_mentah["Label"])
# Out:
# (array([23.,  0., 39.,  0.,  0., 37.,  0., 79.,  0., 22.]),
#  array([0. , 0.4, 0.8, 1.2, 1.6, 2. , 2.4, 2.8, 3.2, 3.6, 4. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(data_mentah["Spending Score (1-100)"])
# Out:
# (array([16., 20., 10., 17., 35., 37., 11., 24., 14., 16.]),
#  array([ 1. , 10.8, 20.6, 30.4, 40.2, 50. , 59.8, 69.6, 79.4, 89.2, 99. ]),
#  <BarContainer object of 10 artists>)
